# %%
import pandas as pd
import yfinance as yf

# %%
# !pip install yahoofinance
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# reading a balance sheet using yahoo finance
from yahoofinance import BalanceSheet

# %%
bs = BalanceSheet('HDFCBANK.NS', locale= '')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 bs = BalanceSheet('HDFCBANK.NS', locale= '')
#
# File c:\Users\Sumeet Maheshwari\AppData\Local\Programs\Python\Python310\lib\site-packages\yahoofinance\balancesheet.py:80, in BalanceSheet.__init__(self, stock, locale)
#      78 super().__init__(locale)
#      79 url = self._base_url + '/{}/financials'.format(stock)
# ---> 80 fin_data = self._fetch_quote_summary(url)
#      82 self.BalanceSheet = self._extract_BalanceSheet(fin_data)
#      83 self.BalanceSheet.sort(key=lambda x: x['endDate']['raw'], reverse=True)
#
# File c:\Users\Sumeet Maheshwari\AppData\Local\Programs\Python\Python310\lib\site-packages\yahoofinance\interfaces.py:53, in IYahooData._fetch_quote_summary(url)
#      50 html = requests.get(url).text
#      51 soup = BeautifulSoup(html,'html.parser')
# ...

# %%
hdfc = yf.Ticker("TATAMOTORS.NS")

# %%
hdfc.balancesheet
# Out:
#                                                        2023-03-31  \
# Ordinary Shares Number                               3829847221.0
# Share Issued                                         3829847221.0
# Net Debt                                           992955300000.0
# Total Debt                                        1396354500000.0
# Tangible Book Value                               -113701300000.0
# ...                                                           ...
# Cash Cash Equivalents And Short Term Investments   556297100000.0
# Other Short Term Investments                       237427600000.0
# Cash And Cash Equivalents                          318869500000.0
# Cash Equivalents                                   236140600000.0
# Cash Financial                                      82728900000.0
#
#                                                        2022-03-31  \
# Ordinary Shares Number                               3829055161.0
# ...

# %%
hdfc.cash_flow.head(50)
# Out:
#                                                     2023-03-31  \
# Free Cash Flow                                  172923300000.0
# Repayment Of Debt                              -634175200000.0
# Issuance Of Debt                                444405100000.0
# Issuance Of Capital Stock                        37696000000.0
# Capital Expenditure                            -180956800000.0
# End Cash Position                               318869500000.0
# Other Cash Adjustment Outside Changein Cash                NaN
# Beginning Cash Position                         381590100000.0
# Effect Of Exchange Rate Changes                  13869900000.0
# Changes In Cash                                 -76590500000.0
# Financing Cash Flow                            -262429000000.0
# Cash Flow From Continuing Financing Activities             NaN
# Net Other Financing Charges                       -420400000.0
# Interest Paid Cff                               -93359600000.0
# ...
